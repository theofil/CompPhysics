# %%
x1 = -2
x2 = 3
x3 = 4
for i in range(20):
    y1 = x1
    y2 = x2
    y3 = x3
    
    x1 = (10 + y2)/3.
    x2 = (5 + y1 + y3)/3
    x3 = (10 + 2*y2)/4
    
print(x1, x2, x3)
# Out:
# 4.999991247644071 4.9999945297775445 4.999986871466106

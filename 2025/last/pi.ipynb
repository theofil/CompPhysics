# %%
import numpy as np
U = np.random.rand

# %%
N = 10**6
n = 0 # hits
r = 1

for i in range(N):
    x = 2*r*U() - r
    y = 2*r*U() - r
    if x**2 + y**2 <= r**2:
        n += 1 # hit

V  = (2*r)**2        
p  = n/N
I  = p*V
δI = V*(p*(1-p))**0.5/N**0.5
print(I,  δI)
# Out:
# 3.140832 0.00164271188824334

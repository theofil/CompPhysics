# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
xn = []
x  = 3655486548

c    = 16807
a    = 0
Nmax = 2**31 - 1
for i in range(50000):
    x = (c*x + a)%Nmax
    # xn += [x] # xn = xn + [x]
    xn += [x/Nmax]

# print(xn)

# %%
plt.hist(xn, bins = [0, 0.3, 0.4, 0.5, 0.6, 0.7, 0.8, 0.9, 1], ec = 'black' )
# plt.hist(xn, bins = np.linspace(0,1,101), ec = 'black' )
# Out:
# (array([14959.,  5077.,  4978.,  5016.,  5037.,  5008.,  5017.,  4908.]),
#  array([0. , 0.3, 0.4, 0.5, 0.6, 0.7, 0.8, 0.9, 1. ]),
#  <BarContainer object of 8 artists>)

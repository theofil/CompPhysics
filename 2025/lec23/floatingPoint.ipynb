# %%
if(0.1 + 0.2 - 0.3 == 0.0):
    print ("True")
else:
    print("False")
# Out:
# False

# %% [markdown]
# ## 7/3 - 4/3 - 3/3

# %%
if(0.5 + 0.5 - 1 == 0.0):
    print ("True")
else:
    print("False")
# Out:
# True

# %%
2**52 + 0.1
# Out:
# 4503599627370496.0

# %%
2**52 - (2**52 + 0.7)
# Out:
# -1.0

# %%
ε = 1
while(1.0 + ε != 1 ): ε = ε/2

print(ε, 2**-53)
# Out:
# 1.1102230246251565e-16 1.1102230246251565e-16

# %%
def f(x): x**2 

(f(x + 2**-52) - f(x))/2**(-52)

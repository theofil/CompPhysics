# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
U = np.random.rand

# %%
# f(x) = 2x
# F^{-1}(x) = √x

xs = [U()**0.5 for i in range(10000) ]

# %%
plt.hist(xs, ec='black')
# Out:
# (array([ 116.,  314.,  516.,  736.,  900., 1115., 1304., 1448., 1686.,
#         1865.]),
#  array([0.01057537, 0.10951188, 0.20844839, 0.3073849 , 0.40632142,
#         0.50525793, 0.60419444, 0.70313095, 0.80206747, 0.90100398,
#         0.99994049]),
#  <BarContainer object of 10 artists>)

# %%
# f(x) = e^x / (e^5 -1)
# F^{-1}(x) = ln(U(e^5 -1)  + 1)

ln = np.log
exp = np.exp

xs = [ ln(U()*(exp(5) - 1) + 1) for i in range(10000) ]

# %%
# xs

# %%
plt.hist(xs, ec='black')
# Out:
# (array([  39.,   95.,  113.,  215.,  306.,  512.,  873., 1408., 2428.,
#         4011.]),
#  array([0.01940222, 0.51745753, 1.01551284, 1.51356815, 2.01162346,
#         2.50967877, 3.00773408, 3.50578939, 4.0038447 , 4.50190001,
#         4.99995532]),
#  <BarContainer object of 10 artists>)

# %%
ln = np.log
exp = np.exp

def f(x): 
    return exp(x)/(exp(5) - 1)

fmax = f(5)

N = 10000
xs = []

for i in range(N):
    x = 5*U()
    y = fmax*U()
    if y < f(x): xs += [x]
        
        
plt.hist(xs, bins = np.arange(0, 5, 0.5), ec='black')
# Out:
# (array([  6.,  15.,  25.,  37.,  52., 105., 172., 267., 497.]),
#  array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5]),
#  <BarContainer object of 9 artists>)
